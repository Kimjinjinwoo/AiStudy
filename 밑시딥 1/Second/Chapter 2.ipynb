# %% [markdown]
# # CHAPTER 2 퍼셉트론

# %% [markdown]
# ## 2-1 퍼셉트론이란?

# %% [markdown]
# ## 2-2 단순한 논리 회로

# %% [markdown]
# ### 2-2-1 AND 게이트

# %% [markdown]
# ### 2-2-2 NAND 게이트와 OR 게이트

# %% [markdown]
# ## 2-3 퍼셉트론 구현하기

# %% [markdown]
# ### 2-3-1 간단한 구현부터

# %%
def AND(x1 , x2):
    w1 , w2 , theta = 0.5 , 0.5 , 0.7
    tmp = x1 * w1 + x2 * w2
    if tmp <= theta:
        return 0
    elif tmp > theta:
        return 1

# %% [markdown]
# ### 2-3-2 가중치와 편향 도입

# %% [markdown]
# ###2-3-3 가중치와 편향 구현하기

# %%
import numpy as np
def AND(x1 , x2):
    x = np.array([x1, x2])
    w = np.array([0.5,0.5])
    b = -0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %%
#NAND와 OR
def NAND(x1 , x2):
    x = np.array([x1 , x2])
    w = np.array([-0.5 , -0.5])
    b = 0.7
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

def OR(x1 , x2):
    x = np.array([x1 , x2])
    w = np.array([0.5,0.5])
    b = -0.2
    tmp = np.sum(w*x) + b
    if tmp <= 0:
        return 0
    else:
        return 1

# %% [markdown]
# ## 2-4 퍼셉트론의 한계

# %% [markdown]
# ### 2-4-1 도전! XOR 게이트

# %% [markdown]
# ### 2-4-2 선형과 비선형

# %% [markdown]
# ### 2-5 다층 퍼셉트론이 출동한다면

# %% [markdown]
# ### 2-5-1 기존 게이트 조합하기

# %% [markdown]
# ### 2-5-2 XOR 게이트 구현하기

# %%
def XOR(x1 , x2):
    s1 = NAND(x1 , x2)
    s2 = OR(x1 , x2)
    y = AND(s1 , s2)
    return y
